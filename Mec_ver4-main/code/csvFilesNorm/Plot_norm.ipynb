# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

data1 = pd.read_csv("DQL_5phut_1.csv").values[:, 1]
data2 = pd.read_csv("DDQL_5phut_1.csv").values[:, 1]
data3 = pd.read_csv("FDQO_5phut_10.8.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, color="red", label = "DQL")
plt.plot(number, [np.average(data1[20:41])] * data1.shape[0], color="red", linestyle = '--')
plt.plot(number, data2, color="green", label = "DDQL")
plt.plot(number, [np.average(data1[20:41])] * data1.shape[0], color="green", linestyle = '--')
plt.plot(number, data3, color="blue", label = "FDQO")
plt.plot(number, [np.average(data1[20:41])] * data1.shape[0], color="blue", linestyle = '--')
plt.legend()
plt.title("900 - 1000 tasks per episode")
plt.show()

plt.clf()
a = 70
b = 120
data4 = pd.read_csv("DQL_5phut_2.csv").values[:, 1]
data5 = pd.read_csv("DDQL_5phut_2.csv").values[:, 1]
data55 = pd.read_csv("DDQL_5phut_21.csv").values[:, 1]
data6 = pd.read_csv("FDQO_5phut_20.8.csv").values[:, 1]
data7 = pd.read_csv("FDQO_5phut_1.8.csv").values[:, 1]
data8 = pd.read_csv("FDQO_5phut_2.0.csv").values[:, 1]
dataFDQO_all_fuzzy = pd.read_csv("FDQO_5phut_all_fuzzy.csv").values[:, 1]
number = [i + 1 for i in range(data4.shape[0])]
plt.plot(number, data4, color="red", label = "DQL")
plt.plot(number, [np.average(data4[a:b])] * data4.shape[0], color="red", linestyle = '--')
plt.plot(number, data5, color="green", label = "DDQL", linestyle = '--')
plt.plot(number, [np.average(data5[a:b])] * data4.shape[0], color="green", linestyle = '--')
plt.plot(number, data55, color="green", label = "DDQL")
plt.plot(number, [np.average(data55[a:b])] * data55.shape[0], color="green", linestyle = '--')
plt.plot(number, data6, color="blue", label = "FDQO 0.8")
plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="blue", linestyle = '--')
plt.plot(number, data7, color="orange", label = "FDQO 0.2")
plt.plot(number, [np.average(data7[a:b])] * data6.shape[0], color="orange", linestyle = '--')
plt.plot(number, data8, color="purple", label = "FDQO 0.0")
plt.plot(number, [np.average(data8[a:b])] * data6.shape[0], color="purple", linestyle = '--')
plt.plot(number, dataFDQO_all_fuzzy, color="gray", label = "all fuzzy")
plt.plot(number, [np.average(dataFDQO_all_fuzzy[a:b])] * data6.shape[0], color="gray", linestyle = '--')
plt.title("1100 - 1200 tasks per episode, average: " + str(a) + " - " + str(b))
plt.legend()
plt.show()

plt.clf()
dataDQL3 = pd.read_csv("DQL_5phut_0.1_de_0.1_70.csv").values[:, 1]
dataDQL4 = pd.read_csv("DQL_5phut_4.csv").values[:, 1]
dataDQL5 = pd.read_csv("DQL_5phut_5.csv").values[:, 1]
dataDQL_0_de_005_70 = pd.read_csv("DQL_5phut_0.1_de_0.05_70.csv").values[:, 1]
plt.plot(number, data4, color="red", label = "DQL eps = 0.1")
plt.plot(number, [np.average(data4[70:120])] * data4.shape[0], color="red", linestyle = '--')
plt.plot(number, dataDQL3, color="green", label = "DQL eps 0.1, 0.1 decreasing every 70k steps")
plt.plot(number, [np.average(dataDQL3[70:120])] * dataDQL3.shape[0], color="green", linestyle = '--')
plt.plot(number, dataDQL4, color="blue", label = "DQL eps 0.1, 0.05 decreasing every 50k steps")
plt.plot(number, [np.average(dataDQL4[70:120])] * dataDQL4.shape[0], color="blue", linestyle = '--')
plt.plot(number, dataDQL5, color="purple", label = "DQL eps 0.2, 0.05 decreasing every 35k steps")
plt.plot(number, [np.average(dataDQL5[70:120])] * dataDQL4.shape[0], color="purple", linestyle = '--')
plt.plot(number, dataDQL_0_de_005_70, color="violet", label = "DQL eps 0.1, 0.05 decreasing every 70k steps")
plt.plot(number, [np.average(dataDQL_0_de_005_70[70:120])] * dataDQL_0_de_005_70.shape[0], color="violet", linestyle = '--')
plt.title("DQL: 1100 - 1200 tasks per episode, average: 70 - 120")
plt.legend()
plt.show()

a = 70
b = 120
plt.rcParams['figure.figsize'] = [12, 9]
plt.clf()
number = [i + 1 for i in range(data4.shape[0])]
dataFDQO_fuzzy_exploration = pd.read_csv("FDQO_5phut_fuzzy_exploration.csv").values[:, 1]
dataFDQO_fuzzy_start = pd.read_csv("FDQO_5phut_fuzzy_start_40.csv").values[:, 1]
dataFDQO_fuzzy_start_3 = pd.read_csv("FDQO_5phut_fuzzy_start_3.csv").values[:, 1]
dataFDQO_fuzzy_exploitation = pd.read_csv("FDQO_5phut_fuzzy_exploitation_70k.csv").values[:, 1]
plt.plot(number, data6, color="blue", label = "FDQO 0.8")
plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="blue", linestyle = '--')
plt.plot(number, data7, color="orange", label = "FDQO 0.2")
plt.plot(number, [np.average(data7[a:b])] * data6.shape[0], color="orange", linestyle = '--')
plt.plot(number, data8, color="purple", label = "FDQO 0.0")
plt.plot(number, [np.average(data8[a:b])] * data6.shape[0], color="purple", linestyle = '--')
plt.plot(number, dataFDQO_all_fuzzy, color="gray", label = "all fuzzy")
plt.plot(number, [np.average(dataFDQO_all_fuzzy[a:b])] * data6.shape[0], color="gray", linestyle = '--')
plt.plot(number, dataFDQO_fuzzy_exploration, color="brown", label = "fuzzy_exploration")
plt.plot(number, [np.average(dataFDQO_fuzzy_exploration[a:b])] * data6.shape[0], color="brown", linestyle = '--')
plt.plot(number, dataFDQO_fuzzy_start, color="black", label = "fuzzy_start_40k")
plt.plot(number, [np.average(dataFDQO_fuzzy_start[a:b])] * data6.shape[0], color="black", linestyle = '--')
plt.plot(number, dataFDQO_fuzzy_start_3, color="black", label = "fuzzy_start_3k", linestyle = "-.")
plt.plot(number, [np.average(dataFDQO_fuzzy_start_3[a:b])] * data6.shape[0], color="black", linestyle = '--')
plt.plot(number, dataFDQO_fuzzy_start_3, color="green", label = "dataFDQO_fuzzy_exploitation")
plt.plot(number, [np.average(dataFDQO_fuzzy_exploitation[a:b])] * data6.shape[0], color="green", linestyle = '--')
plt.title("FDQO: 1100 - 1200 tasks per episode, average: " + str(a) + " - " + str(b))
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

data1 = pd.read_csv("DQL_5phut_third_1.csv").values[:, 1]
data2 = pd.read_csv("DDQL_5phut_third_1.csv").values[:, 1]
data3 = pd.read_csv("FDQO_5phut_third_0.8.csv").values[:, 1]
data4 = pd.read_csv("DQL_5phut_third_base_0.6.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, color="red", label = "DQL")
plt.plot(number, [np.average(data1[50:])] * data1.shape[0], color="red", linestyle = '--')
plt.plot(number, data2, color="green", label = "DDQL")
plt.plot(number, [np.average(data2[50:])] * data1.shape[0], color="green", linestyle = '--')
plt.plot(number, data3, color="gray", label = "FDQO")
plt.plot(number, [np.average(data3[50:])] * data1.shape[0], color="gray", linestyle = '--')
plt.plot(number, data4, color="blue", label = "FDQO")
plt.plot(number, [np.average(data4[50:])] * data1.shape[0], color="blue", linestyle = '--')
plt.legend()
plt.title("800 - 900 tasks per episode")
plt.axis([0, 75, 0, 1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 12]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

a = 50
b = 100
data4 = pd.read_csv("DQL_5phut_2.csv").values[:109, 1]
data5 = pd.read_csv("DDQL_5phut_2.csv").values[:109, 1]
data55 = pd.read_csv("DDQL_5phut_21.csv").values[:109, 1]
data6 = pd.read_csv("FDQO_5phut_20.8.csv").values[:109, 1]
data7 = pd.read_csv("FDQO_5phut_1.8.csv").values[:109, 1]
data8 = pd.read_csv("FDQO_5phut_2.0.csv").values[:109, 1]
data9 = pd.read_csv("DQL_5phut_second_base_0.5.csv").values[:, 1]
data10 = pd.read_csv("DQL_5phut_second_base_0.2.csv").values[:, 1]
print(data9.shape)
dataFDQO_all_fuzzy = pd.read_csv("FDQO_5phut_all_fuzzy.csv").values[:, 1]
number = [i + 1 for i in range(data4.shape[0])]
plt.plot(number, data4, color="red", label = "DQL")
plt.plot(number, [np.average(data4[a:b])] * data4.shape[0], color="red", linestyle = '--')
plt.plot(number, data5, color="green", label = "DDQL", linestyle = '--')
plt.plot(number, [np.average(data5[a:b])] * data4.shape[0], color="green", linestyle = '--')
plt.plot(number, data55, color="green", label = "DDQL")
plt.plot(number, [np.average(data55[a:b])] * data55.shape[0], color="green", linestyle = '--')
# plt.plot(number, data6, color="blue", label = "FDQO 0.8")
# plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="blue", linestyle = '--')
plt.plot(number, data7, color="orange", label = "FDQO 0.2")
plt.plot(number, [np.average(data7[a:b])] * data6.shape[0], color="orange", linestyle = '--')
plt.plot(number, data9, color="purple", label = "DQL base 0.2")
plt.plot(number, [np.average(data9[a:b])] * data6.shape[0], color="purple", linestyle = '--')
plt.plot(number, data10, color="gray", label = "DQL base 0.2 with 0.05 exp")
plt.plot(number, [np.average(data10[a:b])] * data6.shape[0], color="gray", linestyle = '--')
plt.title("1100 - 1200 tasks per episode, average: " + str(a) + " - " + str(b))
plt.legend(loc='upper center', bbox_to_anchor=(0.2, 0.99),
          ncol=2, fancybox=True, shadow=True)
plt.show()
# Out:
# (109,)
