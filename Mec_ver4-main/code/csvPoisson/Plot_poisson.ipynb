# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

a = 50
b = 100
data1 = pd.read_csv("DQL_5phut_linear1.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.plot(number, data1, color="red", label = "DQL")
plt.plot(number, [np.average(data1[a:b])] * data1.shape[0], color="red", linestyle = '--')
plt.title("1100 - 1200 tasks per episode, average: " + str(a) + " - " + str(b))
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

a = 10
b = 80
data1 = pd.read_csv("DQL_5phut_linear2.csv").values[:, 1]
data2 = pd.read_csv("DDQL_5phut_linear2_1.csv").values[:, 1]
data3 = pd.read_csv("FDQO_5phut_linear_fuzzy_only.csv").values[:, 1]
data4 = pd.read_csv("FDQO_5phut_linear2_0.2.csv").values[:, 1]
data5 = pd.read_csv("DQL_5phut_linear2_3_base_0.2.csv").values[:, 1]
data6 = pd.read_csv("DDQL_5phut_linear2_2.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.plot(number, data1, color="red", label = "DQL")
#plt.plot(number, [np.average(data1[a:b])] * data1.shape[0], color="red", linestyle = '--')
plt.plot(number, data2, color="blue", label = "DDQL")
#plt.plot(number, [np.average(data2[a:b])] * data2.shape[0], color="blue", linestyle = '--')
plt.plot(number, data6, color="blue", label = "DDQL", linestyle = '-.')
plt.plot(number, data5, color="green", label = "DQL base 0.2")
#plt.plot(number, [np.average(data4[a:b])] * data5.shape[0], color="green", linestyle = '--')
plt.plot(number, data4, color="purple", label = "FDQO 0.2")
#plt.plot(number, [np.average(data4[a:b])] * data2.shape[0], color="purple", linestyle = '-.')
plt.plot(number, data3, color="orange", label = "Fuzzy only")
#plt.plot(number, [np.average(data3[a:b])] * data2.shape[0], color="green", linestyle = '--')
#plt.title("1100 - 1200 tasks per episode, average: " + str(a) + " - " + str(b))

plt.title("Linear distribution task")
plt.xlabel("Episode")
plt.ylabel("QoS (reward)")
plt.legend(loc ="lower right")
plt.axis([0, 85, 0, 1])
plt.show()

plt.clf()
number_tasks = pd.read_csv("../../data_task/summary.csv").values
b = np.arange(200)
plt.plot(b, number_tasks)
plt.xlabel("Episode")
plt.ylabel("Number of tasks")
plt.axis([0, 85, 0, 2100])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

a = 10
b = 90
data1 = pd.read_csv("DQL_5phut_poisson_2.csv").values[:90, 1]
data2 = pd.read_csv("DDQL_5phut_poisson_1.csv").values[:90, 1]
data3 = pd.read_csv("DQL_5phut_poisson__base_0.2.csv").values[:90, 1]
data4 = pd.read_csv("FDQO_5phut_poisson_0.2.csv").values[:90, 1]
data5 = pd.read_csv("DQL_5phut_poisson_2_base_0.2.csv").values[:90, 1]
data6 = pd.read_csv("FDQO_5phut_fuzzy_only.csv").values[:90, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.plot(number, data1, color="red", label = "DQL")
#plt.plot(number, [np.average(data1[a:b])] * data1.shape[0], color="red", linestyle = '--')
plt.plot(number, data2, color="blue", label = "DDQL")
# #plt.plot(number, [np.average(data2[a:b])] * data2.shape[0], color="blue", linestyle = '--')
plt.plot(number, data3, color="green", label = "DQL base 0.2")
#plt.plot(number, [np.average(data3[a:b])] * data2.shape[0], color="green", linestyle = '--')
plt.plot(number, data4, color="purple", label = "FDQO 0.2")
#plt.plot(number, [np.average(data4[a:b])] * data2.shape[0], color="purple", linestyle = '--')
#plt.plot(number, data5, color="orange", label = "DQL base 0.2")
#plt.plot(number, [np.average(data5[a:b])] * data2.shape[0], color="orange", linestyle = '--')
plt.plot(number, data6, color="orange", label = "Fuzzy only")
#plt.plot(number, [np.average(data6[a:b])] * data2.shape[0], color="gray", linestyle = '--')
#plt.title("1100 - 1200 tasks per episode, average: " + str(a) + " - " + str(b))
plt.title("Poisson distribution task")
plt.xlabel("Episode")
plt.ylabel("QoS (reward)")
plt.legend(loc ="lower right")
plt.axis([0, 80, 0, 1])
plt.show()

plt.clf()
number_tasks = pd.read_csv("../../data_task/200 poisson tasks/summary.csv").values
b = np.arange(200)
plt.plot(b, number_tasks)
plt.title("Poisson distribution task")
plt.xlabel("Episode")
plt.ylabel("Number of tasks")
plt.axis([0, 80, 0, 2100])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
df = pd.read_csv("kq_linear2_0.2.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_linear2_0.2.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
plt.fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
plt.title("Percentage of using Fuzzy table")
plt.xlabel("Episode")
plt.ylabel("%")
plt.axis([0, 90, 0, 1])
plt.show()

plt.clf()
df = pd.read_csv("kqDQN_linear2_3_base_0.2.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("DQL_5phut_linear2_3_base_0.2.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
plt.fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
plt.title("Percentage of exploration")
plt.xlabel("Episode")
plt.ylabel("%")
plt.axis([0, 90, 0, 1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
df = pd.read_csv("kq_poisson_0.2.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_poisson_0.2.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
plt.fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
plt.title("Percentage of using Fuzzy table")
plt.xlabel("Episode")
plt.ylabel("%")
plt.axis([0, 90, 0, 1])
plt.show()

plt.clf()
df = pd.read_csv("kqDQN_poisson__base_0.2.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("DQL_5phut_poisson__base_0.2.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
plt.fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
plt.title("Percentage of exploration")
plt.xlabel("Episode")
plt.ylabel("%")
plt.axis([0, 90, 0, 1])
plt.show()
