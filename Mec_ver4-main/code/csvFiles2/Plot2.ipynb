# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 30]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
figure, axes = plt.subplots(nrows=12, ncols=1)

data1 = pd.read_csv("DQL_5phut_1.csv").values[:, 1]
data2 = pd.read_csv("DDQL_5phut_1.csv").values[:, 1]
data3 = pd.read_csv("FDQO_5phut_1.csv").values[:, 1]
data4 = pd.read_csv("DQL_5phut_2.csv").values[:, 1]
data5 = pd.read_csv("DDQL_5phut_2.csv").values[:, 1]
data6 = pd.read_csv("FDQO_5phut_2.csv").values[:, 1]
data7 = pd.read_csv("DQL_5phut_3.csv").values[:, 1]
data8 = pd.read_csv("DDQL_5phut_3.csv").values[:, 1]
data9 = pd.read_csv("FDQO_5phut_3.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
axes[0].plot(number, data1, color="red", label = "DQL")
axes[0].plot(number, [np.average(data1[20:41])] * data1.shape[0], color="red", linestyle = '--', label = "DQL average since episode 20 - 40")
axes[0].plot(number, data2, color="green", label = "DDQL")
axes[0].plot(number, [np.average(data2[20:41])] * data1.shape[0], color="green", linestyle = '--', label = "DDQL average since episode 20 - 40")
axes[0].plot(number, data3, color="blue", label = "FDQO")
axes[0].plot(number, [np.average(data3[20:41])] * data1.shape[0], color="blue", linestyle = '--', label = "FDQO average since episode 20 - 40")
axes[0].legend()
axes[0].axis([0, 96, 0.8, 1])
axes[0].set_title("96 episodes")

df = pd.read_csv("kq_1.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_1.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
axes[1].fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
axes[1].axis([0, 96, 0, 0.4])

number = [i for i in range(data4.shape[0])]
axes[2].plot(number, data4, color="red", label = "DQL")
axes[2].plot(number, [np.average(data4[125:191])] * data4.shape[0], color="red", linestyle = '--', label = "DQL average since episode 125 - 190")
axes[2].plot(number, data5, color="green", label = "DDQL")
axes[2].plot(number, [np.average(data5[125:191])] * data5.shape[0], color="green", linestyle = '--', label = "DDQL average since episode 125 - 190")
axes[2].plot(number, data6, color="blue", label = "FDQO")
axes[2].plot(number, [np.average(data6[125:191])] * data6.shape[0], color="blue", linestyle = '--', label = "FDQO average since episode 125 - 190")
axes[2].legend()
axes[2].axis([0, 191, 0.85, 1])
axes[2].set_title("190 episodes")

df = pd.read_csv("kq_2.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_2.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
axes[3].fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
axes[3].axis([0, 96, 0, 0.4])

data7 = pd.read_csv("DQL_5phut_3.csv").values[:, 1]
data8 = pd.read_csv("DDQL_5phut_3.csv").values[:, 1]
data9 = pd.read_csv("FDQO_5phut_3.csv").values[:, 1]
data10 = pd.read_csv("FDQO_5phut_3_0.8.csv").values[:, 1]
data11 = pd.read_csv("FDQO_5phut_3_0.5.csv").values[:, 1]
data12 = pd.read_csv("FDQO_5phut_3_0.2.csv").values[:, 1]

number = [i for i in range(data7.shape[0])]
axes[4].plot(number, data7, color="red", label = "DQL")
axes[4].plot(number, [np.average(data7[80:138])] * data7.shape[0], color="red", 
             linestyle = '--', label = "DQL average since episode 80 - 138")
axes[4].plot(number, data8, color="green", label = "DDQL")
axes[4].plot(number, [np.average(data8[80:138])] * data7.shape[0], color="green", 
             linestyle = '--', label = "DDQL average since episode 80 - 138")
axes[4].plot(number, data9, color="blue", label = "FDQO")
axes[4].plot(number, [np.average(data9[80:138])] * data7.shape[0], color="blue", 
             linestyle = '--', label = "FDQO average since episode 80 - 138")
axes[4].legend()
axes[4].axis([0, 138, 0.8, 1])
axes[4].set_title("138 episodes")

df = pd.read_csv("kq_3.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_3.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
axes[5].fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
axes[5].axis([0, 138, 0, 1])

axes[6].plot(number, data9, color="red", label = "FDQO 0.6")
axes[6].plot(number, [np.average(data9[80:138])] * data7.shape[0], color="red", 
             linestyle = '--', label = "FDQO average since episode 80 - 138")
axes[6].plot(number, data10, color="blue", label = "FDQO 0.8")
axes[6].plot(number, [np.average(data10[80:138])] * data7.shape[0], color="blue", 
             linestyle = '--', label = "FDQO average since episode 80 - 138")
axes[6].plot(number, data11, color="green", label = "FDQO 0.5")
axes[6].plot(number, [np.average(data11[80:138])] * data7.shape[0], color="green", 
             linestyle = '--', label = "FDQO average since episode 80 - 138")
axes[6].plot(number, data12, color="orange", label = "FDQO 0.2")
axes[6].plot(number, [np.average(data12[80:138])] * data7.shape[0], color="orange", 
             linestyle = '--', label = "FDQO average since episode 80 - 138")
axes[6].legend()
axes[6].axis([0, 138, 0.7, 1])
axes[6].set_title("138 episodes")

df = pd.read_csv("kq_3_0.8.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_3_0.8.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
axes[7].fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
axes[7].axis([0, 138, 0, 1])

df = pd.read_csv("kq_3_0.5.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_3_0.5.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
axes[8].fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
axes[8].axis([0, 138, 0, 1])

df = pd.read_csv("kq_3_0.2.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_3_0.2.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
axes[9].fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
axes[9].axis([0, 138, 0, 1])

axes[10].plot(number, data7, color="red", label = "DQL")
axes[10].plot(number, [np.average(data7[3:15])] * data7.shape[0], color="red", 
             linestyle = '--', label = "DQL average since episode 3 - 15")
axes[10].plot(number, data8, color="green", label = "DDQL")
axes[10].plot(number, [np.average(data8[3:15])] * data7.shape[0], color="green", 
             linestyle = '--', label = "DDQL average since episode 3 - 15")
axes[10].plot(number, data9, color="blue", label = "FDQO")
axes[10].plot(number, [np.average(data9[3:15])] * data7.shape[0], color="blue", 
             linestyle = '--', label = "FDQO average since episode 3 - 15")
axes[10].legend()
axes[10].axis([0, 20, 0, 1])

axes[11].plot(number, data9, color="red", label = "FDQO 0.6")
axes[11].plot(number, [np.average(data9[0:20])] * data7.shape[0], color="red", 
             linestyle = '--', label = "FDQO average since episode 0 - 20")
axes[11].plot(number, data10, color="blue", label = "FDQO 0.8")
axes[11].plot(number, [np.average(data10[0:20])] * data7.shape[0], color="blue", 
             linestyle = '--', label = "FDQO average since episode 0 - 20")
axes[11].plot(number, data11, color="green", label = "FDQO 0.5")
axes[11].plot(number, [np.average(data11[0:20])] * data7.shape[0], color="green", 
             linestyle = '--', label = "FDQO average since episode 0 - 20")
axes[11].plot(number, data12, color="orange", label = "FDQO 0.2")
axes[11].plot(number, [np.average(data12[0:20])] * data7.shape[0], color="orange", 
             linestyle = '--', label = "FDQO average since episode 0 - 20")
axes[11].axis([0, 20, 0, 1])
axes[11].legend('lower center')

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
figure, axes = plt.subplots(nrows=2, ncols=1)

data1 = pd.read_csv("DQL_5phut_3.csv").values[:, 1]
data2 = pd.read_csv("DDQL_5phut_3.csv").values[:, 1]
data3 = pd.read_csv("FDQO_5phut_rule3_0.8.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
axes[0].plot(number, data1, color="red", label = "DQL")
axes[0].plot(number, [np.average(data1[10:31])] * data1.shape[0], color="red", linestyle = '--',
             label = "DQL average since episode 10 - 30")
axes[0].plot(number, data2, color="green", label = "DDQL")
axes[0].plot(number, [np.average(data2[10:31])] * data1.shape[0], color="green", linestyle = '--',
             label = "DDQL average since episode 10 - 30")
axes[0].plot(number, data3, color="blue", label = "FDQO")
axes[0].plot(number, [np.average(data3[10:31])] * data1.shape[0], color="blue", linestyle = '--',
             label = "FDQO average since episode 10 - 30")
axes[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axes[0].axis([0, 30, 0.4, 1])
axes[0].set_title("96 episodes")

df = pd.read_csv("kq_rule3_0.8.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_rule3_0.8.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]
axes[1].fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
axes[1].axis([0, 96, 0, 0.4])
# Out:
# (0.0, 96.0, 0.0, 0.4)
