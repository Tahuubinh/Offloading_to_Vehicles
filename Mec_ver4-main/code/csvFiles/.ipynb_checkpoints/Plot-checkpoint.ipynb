# %%
import pandas as pd

df = pd.read_csv("kq_full_model2.csv").values
df = df[:297964,0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list

data = pd.read_csv("FDQO_5phut_full_model.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) for sublist in test]

# %%
import matplotlib.pyplot as plt
import matplotlib
plt.style.use('ggplot')
import numpy as np
plt.fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
plt.axis([0, 255, 0, 1])
# Out:
# (0.0, 255.0, 0.0, 1.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DQL_5phut_drop.csv").values[:, 1]
#data2 = pd.read_csv("FDQO_5phut_11.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
plt.title("Dropout 0.2 DQL")
#plt.plot(number, data2)
# Out:
# Text(0.5, 1.0, 'Dropout 0.2 DQL')

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DQL_5phut_dense.csv").values[:, 1]
#data2 = pd.read_csv("FDQO_5phut_11.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
plt.title("Dense DQL")
#plt.plot(number, data2)
# Out:
# Text(0.5, 1.0, 'Dense DQL')
